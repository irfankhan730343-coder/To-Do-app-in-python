# %%
tasks = []   # empty list to store tasks

while True:
    print("\n--- TO DO APP ---")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Delete Task")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        task = input("Enter task: ")
        tasks.append(task)
        print("Task added successfully!")

    elif choice == "2":
        if len(tasks) == 0:
            print("No tasks found.")
        else:
            print("\nYour Tasks:")
            for i in range(len(tasks)):
                print(f"{i+1}. {tasks[i]}")

    elif choice == "3":
        if len(tasks) == 0:
            print("No tasks to delete.")
        else:
            for i in range(len(tasks)):
                print(f"{i+1}. {tasks[i]}")

            num = int(input("Enter task number to delete: "))
            if 1 <= num <= len(tasks):
                removed = tasks.pop(num-1)
                print(f"Removed task: {removed}")
            else:
                print("Invalid task number.")

    elif choice == "4":
        print("Exiting To-Do App. Bye ")
        break

    else:
        print("Invalid choice. Try again.")
# Out:
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice: 5
# Invalid choice. Try again.
#
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice: 1
# Enter task: my name is md irfan
# Task added successfully!
#
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice: 2
#
# Your Tasks:
# 1. my name is md irfan
#
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice: 4
# Exiting To-Do App. Bye
